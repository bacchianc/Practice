# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r'Electric_Vehicle_Population_Data.csv')

# %%
data.head()
# Out:
#    VIN (1-10)  County        City State  Postal Code  Model Year    Make  \
# 0  5UXTA6C05P  Yakima      Yakima    WA      98903.0        2023     BMW
# 1  5YJRE11B48     NaN         NaN    BC          NaN        2008   TESLA
# 2  5YJSA1E24G    King     Seattle    WA      98103.0        2016   TESLA
# 3  1N4AZ1CP5J    King   Shoreline    WA      98177.0        2018  NISSAN
# 4  5YJ3E1EA6J  Island  Coupeville    WA      98239.0        2018   TESLA
#
#       Model                   Electric Vehicle Type  \
# 0        X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 1  ROADSTER          Battery Electric Vehicle (BEV)
# 2   MODEL S          Battery Electric Vehicle (BEV)
# 3      LEAF          Battery Electric Vehicle (BEV)
# 4   MODEL 3          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible              30
# 1           Clean Alternative Fuel Vehicle Eligible             220
# ...

# %%
data.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
data.Make.value_counts()
# Out:
# Make
# TESLA                   69601
# NISSAN                  13649
# CHEVROLET               12242
# FORD                     7817
# BMW                      6620
# KIA                      6534
# TOYOTA                   5386
# VOLKSWAGEN               4238
# VOLVO                    3666
# JEEP                     3468
# HYUNDAI                  3410
# AUDI                     3094
# RIVIAN                   2777
# CHRYSLER                 2755
# MERCEDES-BENZ            1108
# PORSCHE                  1041
# MITSUBISHI                884
# HONDA                     818
# MINI                      810
# FIAT                      797
# POLESTAR                  782
# SUBARU                    640
# SMART                     276
# LINCOLN                   231
# JAGUAR                    225
# MAZDA                     204
# CADILLAC                  191
# LUCID                     191
# LEXUS                     160
# GENESIS                   117
# LAND ROVER                 46
# ...

# %%
data.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 339
# DOL Vehicle ID                                         0
# Vehicle Location                                       7
# Electric Utility                                       3
# ...

# %%
data.drop('Legislative District',axis=1,inplace=True)

# %%
data.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               3
# City                                                 3
# State                                                0
# Postal Code                                          3
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# DOL Vehicle ID                                       0
# Vehicle Location                                     7
# Electric Utility                                     3
# 2020 Census Tract                                    3
# dtype: int64

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %%
data.shape
# Out:
# (153823, 16)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 153823 entries, 0 to 153829
# Data columns (total 16 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         153823 non-null  object
#  1   County                                             153823 non-null  object
#  2   City                                               153823 non-null  object
#  3   State                                              153823 non-null  object
#  4   Postal Code                                        153823 non-null  float64
#  5   Model Year                                         153823 non-null  int64
#  6   Make                                               153823 non-null  object
#  7   Model                                              153823 non-null  object
# ...

# %%
data.head()
# Out:
#    VIN (1-10)  County        City State  Postal Code  Model Year       Make  \
# 0  5UXTA6C05P  Yakima      Yakima    WA      98903.0        2023        BMW
# 2  5YJSA1E24G    King     Seattle    WA      98103.0        2016      TESLA
# 3  1N4AZ1CP5J    King   Shoreline    WA      98177.0        2018     NISSAN
# 4  5YJ3E1EA6J  Island  Coupeville    WA      98239.0        2018      TESLA
# 5  1G1FW6S00H  Kitsap     Seabeck    WA      98380.0        2017  CHEVROLET
#
#      Model                   Electric Vehicle Type  \
# 0       X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL S          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL 3          Battery Electric Vehicle (BEV)
# 5  BOLT EV          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible              30
# ...

# %%
data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].nunique()
# Out:
# 3

# %%
# To drop  county,vin,City,Postal code,model,

data.drop(['VIN (1-10)','County','City','Postal Code','Model'],axis=1,inplace=True)

# %%
data.head()
# Out:
#   State  Model Year       Make                   Electric Vehicle Type  \
# 0    WA        2023        BMW  Plug-in Hybrid Electric Vehicle (PHEV)
# 2    WA        2016      TESLA          Battery Electric Vehicle (BEV)
# 3    WA        2018     NISSAN          Battery Electric Vehicle (BEV)
# 4    WA        2018      TESLA          Battery Electric Vehicle (BEV)
# 5    WA        2017  CHEVROLET          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible              30
# 2           Clean Alternative Fuel Vehicle Eligible             210
# 3           Clean Alternative Fuel Vehicle Eligible             151
# 4           Clean Alternative Fuel Vehicle Eligible             215
# 5           Clean Alternative Fuel Vehicle Eligible             238
#
#    Base MSRP  DOL Vehicle ID                 Vehicle Location  \
# 0          0       227153587    POINT (-120.477805 46.553505)
# ...

# %%
data.State.value_counts()
# Out:
# State
# WA    153487
# CA        91
# VA        34
# MD        33
# TX        19
# IL        13
# NC        13
# CO        11
# AZ        10
# FL        10
# NJ         8
# OR         8
# HI         8
# CT         7
# NY         7
# GA         6
# SC         6
# NV         5
# LA         4
# DC         4
# MO         4
# NE         3
# MA         3
# KY         3
# AL         3
# KS         2
# PA         2
# UT         2
# ID         2
# AR         2
# IN         2
# OH         2
# OK         1
# MN         1
# AK         1
# IA         1
# NH         1
# MT         1
# WY         1
# MS         1
# DE         1
# Name: count, dtype: int64
